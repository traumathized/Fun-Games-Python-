# %% [markdown]
# <a href="https://colab.research.google.com/github/traumathized/Fun-Games-Python-/blob/main/%F0%9F%8E%AE_Rock%2C_Paper%2C_Scissors_Game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

print("🎮 Welcome to Rock, Paper, Scissors Game!")
print("You will play against the computer.\n")
print("Enter your choice: rock, paper, or scissors\n")

# Initialize scores
user_score = 0
computer_score = 0
round_number = 0

while True:
    round_number += 1
    print(f"--- Round {round_number} ---")

    # User input
    user_choice = input("Your choice (rock/paper/scissors) or 'quit' to exit: ").lower()

    if user_choice == "quit":
        print("\nGame Over!")
        print("Final Scores: You =", user_score, "| Computer =", computer_score)
        if user_score > computer_score:
            print("🏆 You won the game!")
        elif user_score < computer_score:
            print("💻 Computer won the game!")
        else:
            print("🤝 It's a tie!")
        break

    # Check valid input
    if user_choice not in ["rock", "paper", "scissors"]:
        print("❌ Invalid choice! Try again.\n")
        continue

    # Computer choice
    computer_choice = random.choice(["rock", "paper", "scissors"])
    print("Computer chose:", computer_choice)

    # Determine winner
    if user_choice == computer_choice:
        print("🤝 It's a tie!\n")
    elif (user_choice == "rock" and computer_choice == "scissors") or \
         (user_choice == "paper" and computer_choice == "rock") or \
         (user_choice == "scissors" and computer_choice == "paper"):
        print("🎉 You win this round!\n")
        user_score += 1
    else:
        print("💻 Computer wins this round!\n")
        computer_score += 1
# Out:
# 🎮 Welcome to Rock, Paper, Scissors Game!
# You will play against the computer.
#
# Enter your choice: rock, paper, or scissors
#
# --- Round 1 ---
# Your choice (rock/paper/scissors) or 'quit' to exit: paper
# Computer chose: paper
# 🤝 It's a tie!
#
# --- Round 2 ---
# Your choice (rock/paper/scissors) or 'quit' to exit: rock
# Computer chose: rock
# 🤝 It's a tie!
#
# --- Round 3 ---
# Your choice (rock/paper/scissors) or 'quit' to exit: rock
# Computer chose: scissors
# 🎉 You win this round!
#
# --- Round 4 ---
# Your choice (rock/paper/scissors) or 'quit' to exit: rock
# Computer chose: rock
# 🤝 It's a tie!
#
# --- Round 5 ---
# Your choice (rock/paper/scissors) or 'quit' to exit: rock
# Computer chose: scissors
# 🎉 You win this round!
#
# --- Round 6 ---
# Your choice (rock/paper/scissors) or 'quit' to exit: rock
# Computer chose: rock
# 🤝 It's a tie!
#
# --- Round 7 ---
# Your choice (rock/paper/scissors) or 'quit' to exit: rock
# Computer chose: paper
# ...
